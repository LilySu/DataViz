# %%
import pandas as pd

shops = pd.read_csv('C:\\Users\\lilyx\\DS-Unit-4-Sprint-1-NLP\\module1-text-data\\data\\yelp_coffeeshop_review_data.csv')
shops.sample(20)
# Out:
#                      coffee_shop_name  \
# 2756                    Bennu Coffee
# 6407     Strange Brew, Austin Coffee
# 4368                          Sa-Ten
# 7547               The Steeping Room
# 555             Apanas Coffee & Beer
# 1973                    Epoch Coffee
# 6537      Quack’s 43rd Street Bakery
# 902           Venezia Italian Gelato
# 2067  The Factory - Cafe With a Soul
# 1655          Summer Moon Coffee Bar
# 3311                     Jo’s Coffee
# 1036                    Epoch Coffee
# 1182              Houndstooth Coffee
# 1538       Figure 8 Coffee Purveyors
# 6498      Quack’s 43rd Street Bakery
# 7258     Emerald Tavern Games & Cafe
# 2083              Houndstooth Coffee
# 3864                  Cream Whiskers
# 5608                   Dominican Joe
# 5655                  Trianon Coffee
#
#                                        full_review_text        star_rating
# 2756   11/4/2015 Updated review Bennu reached out to...   5.0 star rating
# 6407   5/14/2016 1 check-in Not only do they have gr...   5.0 star rating
# 4368   4/15/2016 2 check-ins This review is only for...   3.0 star rating
# 7547   6/25/2016 I love this place! It's great if yo...   5.0 star rating
# 555    3/20/2016 1 check-in Very cute and cozy cafe!...   4.0 star rating
# 1973   10/15/2014 4 check-ins That area needed a goo...   4.0 star rating
# 6537   11/15/2015 The staff there are apparently ver...   4.0 star rating
# 902    11/19/2016 Mmmm the gelato is so tasty! I cam...   4.0 star rating
# 2067   10/16/2016 Amazing coffee! Waffle banana and ...   5.0 star rating
# 1655   10/3/2015 1 check-in Really enjoyed the Half ...   5.0 star rating
# 3311   12/4/2015 Amazing coffee spot that is obvious...   5.0 star rating
# 1036   10/27/2015 I love this place. I've been going...   4.0 star rating
# 1182   10/27/2016 I just had the best experience her...   5.0 star rating
# 1538   2/27/2015 1 check-in This place is a gem in t...   3.0 star rating
# 6498   3/18/2016 If you like thick crust pie (cause ...   4.0 star rating
# 7258   11/29/2014 4 check-ins ROTD 5/10/2015 I am ve...   5.0 star rating
# 2083   9/6/2015 1 check-in I really want to have lik...   3.0 star rating
# 3864   7/26/2016 Cute cafe! I really like the interi...   5.0 star rating
# 5608   2/24/2015 1 check-in One of my favorite coffe...   5.0 star rating
# 5655   6/11/2015 2 check-ins Being the coffee lover ...   4.0 star rating

# %%
import scattertext as st
import spacy
from pprint import pprint

# convention_df = st.SampleCorpora.ConventionData2012.get_data()  
# convention_df.iloc[0]
nlp = spacy.load("en_core_web_md")
corpus = st.CorpusFromPandas(shops, 
                             category_col='star_rating', 
                             text_col='full_review_text',
                             nlp=nlp).build()

# %%
term_freq_df['poorratingscore'] = corpus.get_scaled_f_scores(' 1.0 star rating ')
pprint(list(term_freq_df.sort_values(by='poorratingscore', ascending=False).index[:10]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2aa1ba66de57> in <module>
# ----> 1 term_freq_df['poorratingscore'] = corpus.get_scaled_f_scores(' 1.0 star rating ')
#       2 pprint(list(term_freq_df.sort_values(by='poorratingscore', ascending=False).index[:10]))
#
# NameError: name 'corpus' is not defined

# %%
term_freq_df.sort_values(by= 'poorratingscore', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-195cc9831a9d> in <module>
# ----> 1 term_freq_df.sort_values(by= 'poorratingscore', ascending = False)
#
# NameError: name 'term_freq_df' is not defined

# %%
html = st.produce_scattertext_explorer(corpus,
         category=' 1.0 star rating ',
         category_name='Poor Yelp Rating',
         not_category_name='High Yelp Rating',
         width_in_pixels=1000,
         metadata=shops['coffee_shop_name'])
open("Yelp-CoffeeShop-Visualization.html", 'wb').write(html.encode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-304ff3c55727> in <module>
# ----> 1 html = st.produce_scattertext_explorer(corpus,
#       2          category=' 1.0 star rating ',
#       3          category_name='Poor Yelp Rating',
#       4          not_category_name='High Yelp Rating',
#       5          width_in_pixels=1000,
#
# NameError: name 'st' is not defined
