# %%
import pandas as pd
import requests
import json
pd.options.display.max_rows = 999
pd.set_option('display.max_columns', None)

# %%
response = requests.get('https://api.census.gov/data/2010/dec/sf1?get=H001001,NAME&for=state:*&key=b344a48ff4252c9bef64c656ace82f6d52a66c4')
print(response.status_code)
# Out:
# 200

# %%
response = requests.get('https://api.census.gov/data/2010/dec/sf1/variables/GEO_ID.json')
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# jprint(response.json())

dic["concept"].replace(";", ",").split(',')

di = {}
for header, value in zip(dic["concept"].replace(";", ",").split(','), dic["group"].split(',')):
    di[header] = [value]
pd.DataFrame.from_dict(di)
# Out:
#   HOUSING UNITS TOTAL POPULATION IN OCCUPIED HOUSING UNITS  \
# 0          P38B                                       P38A
#
#   TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE  \
# 0                                               P38D
#
#   TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (WHITE ALONE HOUSEHOLDER)  \
# 0                                               P38C
#
#   TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)  \
# 0                                               P38I
#
#   TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (AMERICAN INDIAN AND ALASKA NATIVE ALONE HOUSEHOLDER)  \
# 0                                               P38F
#
#   TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (ASIAN ALONE HOUSEHOLDER)  \
# 0                                               P38E
#
#   TOTAL POPULATION IN OCCUPIED HOUSING UNITS BY TENURE (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE HOUSEHOLDER)  \
# ...

# %%
import json

def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)

# jprint(response.json())

# %%
response = requests.get('https://api.census.gov/data/2010/dec/aian?get=NAME,PCO001001&for=state%20(or%20part):22&in=metropolitan%20statistical%20area/micropolitan%20statistical%20area:10020')
def jprint(obj):
    # create a formatted string of the Python JSON object
    text = json.dumps(obj, sort_keys=True, indent=4)
    print(text)
jprint(response.json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dfe177de0f1f> in <module>
# ----> 1 response = requests.get('https://api.census.gov/data/2010/dec/aian?get=NAME,PCO001001&for=state:06')
#       2 def jprint(obj):
#       3     # create a formatted string of the Python JSON object
#       4     text = json.dumps(obj, sort_keys=True, indent=4)
#       5     print(text)
#
# NameError: name 'requests' is not defined
